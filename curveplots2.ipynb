# %% [markdown]
# <img height="45px" src="https://colab.research.google.com/img/colab_favicon.ico" align="left" hspace="10px" vspace="0px">
#
# <h1>Welcome to Colaboratory!</h1>
#
# Colaboratory is a free Jupyter notebook environment that requires no setup and runs entirely in the cloud.
#
# With Colaboratory you can write and execute code, save and share your analyses, and access powerful computing resources, all for free from your browser.

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

dataset=pd.read_csv("Project_logs - Sheet1 (3).csv")

#print(dataset)

no_of_procs=dataset.iloc[:,0].values
prob_size=dataset.iloc[:,1].values
exec_time=dataset.iloc[:,2].values

#print(exec_time)

exec_avg0=[0]*8
for i in range(0,8):
  for j in range(0,len(no_of_procs)):
    if(no_of_procs[j]==0 and prob_size[j]==101+10*i):
      exec_avg0[i]=exec_avg0[i]+exec_time[j]
      #print(exec_time[j])
  exec_avg0[i]=exec_avg0[i]/10
print(exec_avg0)

exec_avg1=[0]*8
for i in range(0,8):
  for j in range(0,len(no_of_procs)):
    if(no_of_procs[j]==1 and prob_size[j]==101+10*i):
      exec_avg1[i]=exec_avg1[i]+exec_time[j]
      #print(exec_time[j])
  exec_avg1[i]=exec_avg1[i]/10
print(exec_avg1)

exec_avg2=[0]*8
for i in range(0,8):
  for j in range(0,len(no_of_procs)):
    if(no_of_procs[j]==2 and prob_size[j]==101+10*i):
      exec_avg2[i]=exec_avg2[i]+exec_time[j]
      #print(exec_time[j])
  exec_avg2[i]=exec_avg2[i]/10
print(exec_avg2)

exec_avg3=[0]*8
for i in range(0,8):
  for j in range(0,len(no_of_procs)):
    if(no_of_procs[j]==3 and prob_size[j]==101+10*i):
      exec_avg3[i]=exec_avg3[i]+exec_time[j]
      #print(exec_time[j])
  exec_avg3[i]=exec_avg3[i]/10
print(exec_avg3)

exec_avg4=[0]*8
for i in range(0,8):
  for j in range(0,len(no_of_procs)):
    if(no_of_procs[j]==4 and prob_size[j]==101+10*i):
      exec_avg4[i]=exec_avg4[i]+exec_time[j]
      #print(exec_time[j])
  exec_avg4[i]=exec_avg4[i]/10
print(exec_avg4)

arr=[101,111,121,131,141,151,161,171]
plt.plot(arr,exec_avg0,label='0 threads')
plt.plot(arr,exec_avg1,label='1 thread')
plt.plot(arr,exec_avg2,label='2 threads')
plt.plot(arr,exec_avg3,label='3 threads')
plt.plot(arr,exec_avg0,label='4 threads')
plt.legend()
plt.title('Execution time vs problem size')
plt.xlabel('Problem Size')
plt.ylabel('Execution Time')
# Out:
# [147.0, 158.0, 192.0, 268.0, 356.0, 1270.0, 2245.0, 3392.0]
# [165.0, 182.0, 220.0, 387.0, 689.0, 2240.0, 3514.0, 4097.0]
# [90.0, 104.0, 118.0, 174.0, 218.0, 718.0, 1418.0, 2062.0]
# [60.0, 75.0, 90.0, 117.0, 155.0, 651.0, 1131.0, 1732.0]
# [45.0, 57.0, 65.0, 88.0, 121.0, 432.0, 739.0, 1148.0]
# Text(0, 0.5, 'Execution Time')

# %%
speedup0=[0]*8
speedup1=[0]*8
speedup2=[0]*8
speedup3=[0]*8
speedup4=[0]*8

for i in range(0,8):
  speedup0[i]=exec_avg0[i]/exec_avg0[i]
  speedup1[i]=exec_avg0[i]/exec_avg1[i]
  speedup2[i]=exec_avg0[i]/exec_avg2[i]
  speedup3[i]=exec_avg0[i]/exec_avg3[i]
  speedup4[i]=exec_avg0[i]/exec_avg4[i]
  
arr=[101,111,121,131,141,151,161,171]
plt.plot(arr,speedup0,label='0 threads')
plt.plot(arr,speedup1,label='1 thread')
plt.plot(arr,speedup2,label='2 threads')
plt.plot(arr,speedup3,label='3 threads')
plt.plot(arr,speedup4,label='4 threads')
plt.legend()
plt.title('Speedup vs problem size')
plt.xlabel('Problem Size')
plt.ylabel('Speedup')
# Out:
# Text(0, 0.5, 'Speedup')

# %%
eff1=[0]*8
eff2=[0]*8
eff3=[0]*8
eff4=[0]*8

for i in range(0,8):
  
  eff1[i]=speedup1[i]/1
  eff2[i]=speedup2[i]/2
  eff3[i]=speedup3[i]/3
  eff4[i]=speedup4[i]/4

arr=[101,111,121,131,141,151,161,171]
#plt.plot(arr,eff1,label='1 threads')
plt.plot(arr,eff2,label='2 threads')
plt.plot(arr,eff3,label='3 threads')
#plt.plot(arr,eff4,label='4 threads')
plt.legend()
plt.title('Efficiency vs problem size')
plt.xlabel('Problem Size')
plt.ylabel('Efficiency')
# Out:
# Text(0, 0.5, 'Efficiency')

# %%
exec0=[0]*5
for i in range(0,5):
  for j in range(0,len(no_of_procs)):
    if(no_of_procs[j]==i and prob_size[j]==101):
      exec0[i]=exec0[i]+exec_time[j]
      #print(exec_time[j])
  exec0[i]=exec0[i]/10
print(exec0)

exec1=[0]*5
for i in range(0,5):
  for j in range(0,len(no_of_procs)):
    if(no_of_procs[j]==i and prob_size[j]==111):
      exec1[i]=exec1[i]+exec_time[j]
      #print(exec_time[j])
  exec1[i]=exec1[i]/10
print(exec1)

exec2=[0]*5
for i in range(0,5):
  for j in range(0,len(no_of_procs)):
    if(no_of_procs[j]==i and prob_size[j]==121):
      exec2[i]=exec2[i]+exec_time[j]
      #print(exec_time[j])
  exec2[i]=exec2[i]/10
print(exec2)

exec3=[0]*5
for i in range(0,5):
  for j in range(0,len(no_of_procs)):
    if(no_of_procs[j]==i and prob_size[j]==131):
      exec3[i]=exec3[i]+exec_time[j]
      #print(exec_time[j])
  exec3[i]=exec3[i]/10
print(exec3)

exec4=[0]*5
for i in range(0,5):
  for j in range(0,len(no_of_procs)):
    if(no_of_procs[j]==i and prob_size[j]==141):
      exec4[i]=exec4[i]+exec_time[j]
      #print(exec_time[j])
  exec4[i]=exec4[i]/10
print(exec4)

exec5=[0]*5
for i in range(0,5):
  for j in range(0,len(no_of_procs)):
    if(no_of_procs[j]==i and prob_size[j]==151):
      exec5[i]=exec5[i]+exec_time[j]
      #print(exec_time[j])
  exec5[i]=exec5[i]/10
print(exec5)

exec6=[0]*5
for i in range(0,5):
  for j in range(0,len(no_of_procs)):
    if(no_of_procs[j]==i and prob_size[j]==161):
      exec6[i]=exec6[i]+exec_time[j]
      #print(exec_time[j])
  exec6[i]=exec6[i]/10
print(exec6)

exec7=[0]*5
for i in range(0,5):
  for j in range(0,len(no_of_procs)):
    if(no_of_procs[j]==i and prob_size[j]==171):
      exec7[i]=exec7[i]+exec_time[j]
      #print(exec_time[j])
  exec7[i]=exec7[i]/10
print(exec7)


arr=[0,1,2,3,4]
plt.plot(arr,exec0,label='Problem size=101')
plt.plot(arr,exec1,label='Problem size=111')
plt.plot(arr,exec2,label='Problem size=121')
plt.plot(arr,exec3,label='Problem size=131')
plt.plot(arr,exec4,label='Problem size=141')
plt.plot(arr,exec5,label='Problem size=151')
plt.plot(arr,exec6,label='Problem size=161')
plt.plot(arr,exec7,label='Problem size=171')
plt.legend()
plt.title('Execution Time vs No of Processors')
plt.xlabel('No of Processors')
plt.ylabel('Execution Time')
# Out:
# [147.0, 165.0, 90.0, 60.0, 45.0]
# [158.0, 182.0, 104.0, 75.0, 57.0]
# [192.0, 220.0, 118.0, 90.0, 65.0]
# [268.0, 387.0, 174.0, 117.0, 88.0]
# [356.0, 689.0, 218.0, 155.0, 121.0]
# [1270.0, 2240.0, 718.0, 651.0, 432.0]
# [2245.0, 3514.0, 1418.0, 1131.0, 739.0]
# [3392.0, 4097.0, 2062.0, 1732.0, 1148.0]
# Text(0, 0.5, 'Execution Time')

# %%
sup0=[0]*5
sup1=[0]*5
sup2=[0]*5
sup3=[0]*5
sup4=[0]*5
sup5=[0]*5
sup6=[0]*5
sup7=[0]*5

for i in range(0,5):
  sup0[i]=exec0[0]/exec0[i]
  sup1[i]=exec0[0]/exec1[i]
  sup2[i]=exec0[0]/exec2[i]
  sup3[i]=exec0[0]/exec3[i]
  sup4[i]=exec0[0]/exec4[i]
  sup5[i]=exec0[0]/exec5[i]
  sup6[i]=exec0[0]/exec6[i]
  sup7[i]=exec0[0]/exec7[i]
  
arr=[0,1,2,3,4]
plt.plot(arr,sup0,label='Problem size=101')
plt.plot(arr,sup1,label='Problem size=121')
plt.plot(arr,sup2,label='Problem size=121')
plt.plot(arr,sup3,label='Problem size=131')
plt.plot(arr,sup4,label='Problem size=141')
plt.plot(arr,sup5,label='Problem size=151')
plt.plot(arr,sup6,label='Problem size=161')
plt.plot(arr,sup7,label='Problem size=171')
plt.legend()
plt.title('Speedup vs No of Processors')
plt.xlabel('No of Processors')
plt.ylabel('Speedup')
# Out:
# Text(0, 0.5, 'Speedup')

# %%
e0=[0]*4
e1=[0]*4
e2=[0]*4
e3=[0]*4
e4=[0]*4
e5=[0]*4
e6=[0]*4
e7=[0]*4

for i in range(0,4):
  e0[i]=sup0[i]/(i+1)  
  e1[i]=sup1[i]/(i+1)
  e2[i]=sup2[i]/(i+1)
  e3[i]=sup3[i]/(i+1)
  e4[i]=sup4[i]/(i+1)
  e5[i]=sup5[i]/(i+1)
  e6[i]=sup6[i]/(i+1)
  e7[i]=sup7[i]/(i+1)
  
arr=[1,2,3,4]
plt.plot(arr,e0,label='Problem size=101')
plt.plot(arr,e1,label='Problem size=121')
plt.plot(arr,e2,label='Problem size=121')
plt.plot(arr,e3,label='Problem size=131')
plt.plot(arr,e4,label='Problem size=141')
plt.plot(arr,e5,label='Problem size=151')
plt.plot(arr,e6,label='Problem size=161')
plt.plot(arr,e7,label='Problem size=171')
plt.legend()
plt.title('Efficiency vs No of Processors')
plt.xlabel('No of Processors')
plt.ylabel('Efficiency')
# Out:
# Text(0, 0.5, 'Efficiency')

# %%
perf0=[0]*8
perf4=[0]*8

arr=[101,111,121,131,141,151,161,171]
for i in range(0,8):
  perf0[i]=(arr[i]*arr[i]*arr[i]*2500)/exec_avg0[i]
  perf4[i]=(arr[i]*arr[i]*arr[i]*2500)/exec_avg4[i]
    
plt.plot(arr,perf0,label='0 threads')
plt.plot(arr,perf4,label='4 threads')
plt.legend()
plt.title('Performance vs Problem size')
plt.xlabel('Problem size')
plt.ylabel('Performance')
# Out:
# Text(0, 0.5, 'Performance')

# %%
performance0=[0]*5
performance1=[0]*5
performance2=[0]*5
performance3=[0]*5
performance4=[0]*5
performance5=[0]*5
performance6=[0]*5
performance7=[0]*5
performance8=[0]*5

arr=[0,1,2,3,4]
for i in range(0,5):
  performance0[i]=(101*101*101*2500)/exec0[i]
  performance1[i]=(111*111*111*2500)/exec1[i]
  performance2[i]=(121*121*121*2500)/exec2[i]
  performance3[i]=(131*131*131*2500)/exec3[i]
  performance4[i]=(141*141*141*2500)/exec4[i]
  performance5[i]=(151*151*151*2500)/exec5[i]
  performance6[i]=(161*161*161*2500)/exec6[i]
  performance7[i]=(171*171*171*2500)/exec7[i]
  
plt.plot(arr,performance0,label='Problem size=101')
plt.plot(arr,performance1,label='Problem size=111')
plt.plot(arr,performance2,label='Problem size=121')
plt.plot(arr,performance3,label='Problem size=131')
plt.plot(arr,performance4,label='Problem size=141')
plt.plot(arr,performance5,label='Problem size=151')
plt.plot(arr,performance6,label='Problem size=161')
plt.plot(arr,performance7,label='Problem size=171')
plt.legend()
plt.title('Performance vs No of processors')
plt.xlabel('No of Processors')
plt.ylabel('Performance')
# Out:
# Text(0, 0.5, 'Performance')

# %%
#@title Introducing Colaboratory
#@markdown This 3-minute video gives an overview of the key features of Colaboratory:
from IPython.display import YouTubeVideo
YouTubeVideo('inN8seMm7UI', width=600, height=400)
# Out:
#         <iframe
#             width="600"
#             height=400"
#             src="https://www.youtube.com/embed/inN8seMm7UI"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Getting Started
#
# The document you are reading is a  [Jupyter notebook](https://jupyter.org/), hosted in Colaboratory. It is not a static page, but an interactive environment that lets you write and execute code in Python and other languages.
#
# For example, here is a **code cell** with a short Python script that computes a value, stores it in a variable, and prints the result:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# To execute the code in the above cell, select it with a click and then either press the ▷ button to the left of the code, or use the keyboard shortcut "⌘/Ctrl+Enter".
#
# All cells modify the same global state, so variables that you define by executing a cell can be used in other cells:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# For more information about working with Colaboratory notebooks, see [Overview of Colaboratory](/notebooks/basic_features_overview.ipynb).

# %% [markdown]
# ## More Resources
#
# Learn how to make the most of Python, Jupyter, Colaboratory, and related tools with these resources:
#
# ### Working with Notebooks in Colaboratory
# - [Overview of Colaboratory](/notebooks/basic_features_overview.ipynb)
# - [Guide to Markdown](/notebooks/markdown_guide.ipynb)
# - [Importing libraries and installing dependencies](/notebooks/snippets/importing_libraries.ipynb)
# - [Saving and loading notebooks in GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/master/notebooks/colab-github-demo.ipynb)
# - [Interactive forms](/notebooks/forms.ipynb)
# - [Interactive widgets](/notebooks/widgets.ipynb)
#
# ### Working with Data
# - [Loading data: Drive, Sheets, and Google Cloud Storage](/notebooks/io.ipynb)
# - [Charts: visualizing data](/notebooks/charts.ipynb)
# - [Getting started with BigQuery](/notebooks/bigquery.ipynb)
#
# ### Machine Learning Crash Course
# These are a few of the notebooks from Google's online Machine Learning course. See the [full course website](https://developers.google.com/machine-learning/crash-course/) for more.
# - [Intro to Pandas](/notebooks/mlcc/intro_to_pandas.ipynb)
# - [Tensorflow concepts](/notebooks/mlcc/tensorflow_programming_concepts.ipynb)
# - [First steps with TensorFlow](/notebooks/mlcc/first_steps_with_tensor_flow.ipynb)
# - [Intro to neural nets](/notebooks/mlcc/intro_to_neural_nets.ipynb)
# - [Intro to sparse data and embeddings](/notebooks/mlcc/intro_to_sparse_data_and_embeddings.ipynb)
#
# ### Using Accelerated Hardware
# - [TensorFlow with GPUs](/notebooks/gpu.ipynb)
# - [TensorFlow with TPUs](/notebooks/tpu.ipynb)

# %% [markdown]
# ## Machine Learning Examples: Seedbank
#
# To see end-to-end examples of the interactive machine learning analyses that Colaboratory makes possible, check out the [Seedbank](https://research.google.com/seedbank/) project.
#
# A few featured examples:
#
# - [Neural Style Transfer](https://research.google.com/seedbank/seed/neural_style_transfer_with_tfkeras): Use deep learning to transfer style between images.
# - [EZ NSynth](https://research.google.com/seedbank/seed/ez_nsynth): Synthesize audio with WaveNet auto-encoders.
# - [Fashion MNIST with Keras and TPUs](https://research.google.com/seedbank/seed/fashion_mnist_with_keras_and_tpus): Classify fashion-related images with deep learning.
# - [DeepDream](https://research.google.com/seedbank/seed/deepdream): Produce DeepDream images from your own photos.
# - [Convolutional VAE](https://research.google.com/seedbank/seed/convolutional_vae): Create a generative model of handwritten digits.
